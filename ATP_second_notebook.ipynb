# %%
import pandas as pd
import numpy as np
df_atp = pd.read_csv("C:\\Users\\Patrick\\Documents\\Sport_bets\\atp_data.csv")
df = df_atp.sort_values("elo_loser", ascending = False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Replace 'Winner' and 'elo_winner' with the actual column names 
df = df.sort_values("elo_loser", ascending = False)
print (df.head(10))
winner_elo = df.groupby('Loser')['elo_loser'].mean().sort_values()
winner_elo = winner_elo.head(40)
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x=winner_elo.index, y=winner_elo.values, palette='viridis')

# Set labels and title
plt.xlabel('Player')
plt.ylabel('Average Elo Rating')
plt.title('Average Elo Rating for Each Player')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
#        ATP      Location                   Tournament        Date  \
# 39427   17        Dubai    Dubai Tennis Championships  2016-02-25
# 39725   23   Monte Carlo          Monte Carlo Masters  2016-04-13
# 40012   30          Rome  Internazionali BNL d'Italia  2016-05-15
# 38829   66        London                  Masters Cup  2015-11-17
# 40461   39        London                    Wimbledon  2016-07-02
# 37563   33         Paris                  French Open  2015-06-07
# 41034   52      New York                      US Open  2016-09-11
# 38179   49      Montreal               Rogers Masters  2015-08-16
# 34347   19  Indian Wells             BNP Paribas Open  2013-03-16
# 36002   58      Shanghai             Shanghai Masters  2013-10-12
#
#              Series    Court Surface          Round  Best of          Winner  \
# 39427        ATP500  Outdoor    Hard  Quarterfinals        3        Lopez F.
# 39725  Masters 1000  Outdoor    Clay      2nd Round        3       Vesely J.
# 40012  Masters 1000  Outdoor    Clay      The Final        3       Murray A.
# 38829   Masters Cup   Indoor    Hard    Round Robin        3      Federer R.
# 40461    Grand Slam  Outdoor   Grass      3rd Round        5      Querrey S.
# 37563    Grand Slam  Outdoor    Clay      The Final        5     Wawrinka S.
# 41034    Grand Slam  Outdoor    Hard      The Final        5     Wawrinka S.
# 38179  Masters 1000  Outdoor    Hard      The Final        3       Murray A.
# 34347  Masters 1000  Outdoor    Hard     Semifinals        3  Del Potro J.M.
# 36002  Masters 1000  Outdoor    Hard     Semifinals        3  Del Potro J.M.
#
#        ... Wsets  Lsets    Comment    PSW   PSL  B365W  B365L   elo_winner  \
# 39427  ...   1.0    0.0    Retired  25.50  1.02  17.00   1.02  1717.123938
# 39725  ...   2.0    1.0  Completed  24.52  1.02  23.00   1.01  1564.862585
# 40012  ...   2.0    0.0  Completed   2.93  1.47   2.75   1.44  2122.176874
# 38829  ...   2.0    0.0  Completed   3.70  1.33   3.50   1.30  2162.450958
# 40461  ...   3.0    1.0  Completed  31.30  1.01  26.00   1.01  1685.411193
# 37563  ...   3.0    1.0  Completed   6.87  1.15   6.00   1.12  1984.036047
# 41034  ...   3.0    1.0  Completed   3.62  1.35   3.40   1.33  1975.873547
# 38179  ...   2.0    1.0  Completed   2.98  1.46   2.75   1.44  2122.791662
# 34347  ...   2.0    1.0  Completed   5.69  1.19   6.50   1.11  2090.750006
# 36002  ...   2.0    0.0  Completed   3.62  1.34   3.50   1.30  2028.121305
#
#          elo_loser  proba_elo
# 39427  2392.595567   0.020069
# 39725  2383.577360   0.008899
# 40012  2377.614787   0.186879
# 38829  2368.750636   0.233696
# 40461  2367.959456   0.019283
# 37563  2358.658706   0.103725
# 41034  2355.895420   0.100871
# 38179  2348.716792   0.214076
# 34347  2337.461666   0.194632
# 36002  2334.540780   0.146304
#
# [10 rows x 23 columns]

# %%
import pandas as pd


# und die Elos in den Spalten 'elo_winner' und 'elo_loser' sind

# Kombinieren Sie die Daten aus den Spalten 'Winner' und 'elo_winner'
winner_elo = df[['Winner', 'elo_winner']].rename(columns={'Winner': 'Player', 'elo_winner': 'Elo'})

# Kombinieren Sie die Daten aus den Spalten 'Loser' und 'elo_loser'
loser_elo = df[['Loser', 'elo_loser']].rename(columns={'Loser': 'Player', 'elo_loser': 'Elo'})

# Kombinieren Sie beide DataFrames
combined_elo = pd.concat([winner_elo, loser_elo])

# Berechnen Sie den Durchschnitt der Elo-Wertungen für jeden Spieler
average_elo = combined_elo.groupby('Player')['Elo'].mean().sort_values()

# Drucken Sie den Spieler mit der niedrigsten Durchschnitts-Elo aus
print("Spieler mit der niedrigsten Durchschnitts-Elo:")
print(average_elo.head(1))
df.head(100)
# Out:
# Spieler mit der niedrigsten Durchschnitts-Elo:
# Player
# Diaz J.    1400.897222
# Name: Elo, dtype: float64
#        ATP     Location                   Tournament        Date  \
# 39427   17       Dubai    Dubai Tennis Championships  2016-02-25
# 39725   23  Monte Carlo          Monte Carlo Masters  2016-04-13
# 40012   30         Rome  Internazionali BNL d'Italia  2016-05-15
# 38829   66       London                  Masters Cup  2015-11-17
# 40461   39       London                    Wimbledon  2016-07-02
# ...    ...          ...                          ...         ...
# 31051    3         Doha       Qatar Exxon Mobil Open  2012-01-06
# 24876   46     Montreal               Rogers Masters  2009-08-15
# 41029   52     New York                      US Open  2016-09-07
# 38838   66       London                  Masters Cup  2015-11-22
# 42581   29       Madrid            Mutua Madrid Open  2017-05-13
#
#              Series    Court Surface          Round  Best of          Winner  \
# 39427        ATP500  Outdoor    Hard  Quarterfinals        3        Lopez F.
# 39725  Masters 1000  Outdoor    Clay      2nd Round        3       Vesely J.
# 40012  Masters 1000  Outdoor    Clay      The Final        3       Murray A.
# 38829   Masters Cup   Indoor    Hard    Round Robin        3      Federer R.
# 40461    Grand Slam  Outdoor   Grass      3rd Round        5      Querrey S.
# ...             ...      ...     ...            ...      ...             ...
# 31051        ATP250  Outdoor    Hard     Semifinals        3     Tsonga J.W.
# 24876  Masters 1000  Outdoor    Hard  Quarterfinals        3  Del Potro J.M.
# 41029    Grand Slam  Outdoor    Hard  Quarterfinals        5    Nishikori K.
# 38838   Masters Cup   Indoor    Hard      The Final        3     Djokovic N.
# 42581  Masters 1000  Outdoor    Clay     Semifinals        3        Nadal R.
#
#        ... Wsets  Lsets    Comment    PSW   PSL  B365W  B365L   elo_winner  \
# 39427  ...   1.0    0.0    Retired  25.50  1.02  17.00   1.02  1717.123938
# 39725  ...   2.0    1.0  Completed  24.52  1.02  23.00   1.01  1564.862585
# 40012  ...   2.0    0.0  Completed   2.93  1.47   2.75   1.44  2122.176874
# 38829  ...   2.0    0.0  Completed   3.70  1.33   3.50   1.30  2162.450958
# 40461  ...   3.0    1.0  Completed  31.30  1.01  26.00   1.01  1685.411193
# ...    ...   ...    ...        ...    ...   ...    ...    ...          ...
# 31051  ...   NaN    NaN   Walkover   2.62  1.57   2.37   1.53  2022.122735
# 24876  ...   2.0    0.0  Completed    NaN   NaN   2.37   1.53  2029.399432
# 41029  ...   3.0    2.0  Completed   6.08  1.17   5.50   1.14  2004.941487
# 38838  ...   2.0    0.0  Completed   1.40  3.27   1.44   2.75  2353.206734
# 42581  ...   2.0    0.0  Completed   1.45  3.03   1.44   2.75  2104.438279
#
#          elo_loser  proba_elo
# 39427  2392.595567   0.020069
# 39725  2383.577360   0.008899
# 40012  2377.614787   0.186879
# 38829  2368.750636   0.233696
# 40461  2367.959456   0.019283
# ...            ...        ...
# 31051  2203.013519   0.260901
# 24876  2202.077546   0.270120
# 41029  2201.911543   0.243451
# 38838  2201.723619   0.705163
# 42581  2201.166294   0.364286
#
# [100 rows x 23 columns]

# %%
wins_count = df['Winner'].value_counts()

# Display the count of wins for each player
print(wins_count.head(40))
winner = wins_count.head(40)
winner
# Out:
# Winner
# Federer R.          970
# Nadal R.            803
# Djokovic N.         687
# Ferrer D.           632
# Murray A.           560
# Roddick A.          538
# Berdych T.          524
# Verdasco F.         454
# Davydenko N.        453
# Gasquet R.          450
# Robredo T.          438
# Youzhny M.          428
# Hewitt L.           424
# Wawrinka S.         408
# Lopez F.            405
# Simon G.            389
# Ferrero J.C.        384
# Tsonga J.W.         374
# Monfils G.          372
# Almagro N.          370
# Cilic M.            364
# Kohlschreiber P.    363
# Haas T.             362
# Ljubicic I.         359
# Del Potro J.M.      359
# Stepanek R.         344
# Nalbandian D.       340
# Nieminen J.         333
# Blake J.            333
# Moya C.             331
# Gonzalez F.         324
# Melzer J.           311
# Isner J.            305
# Karlovic I.         305
# Baghdatis M.        305
# Monaco J.           302
# Safin M.            300
# Chela J.I.          293
# Seppi A.            290
# Querrey S.          285
# Name: count, dtype: int64
# Winner
# Federer R.          970
# Nadal R.            803
# Djokovic N.         687
# Ferrer D.           632
# Murray A.           560
# Roddick A.          538
# Berdych T.          524
# Verdasco F.         454
# Davydenko N.        453
# Gasquet R.          450
# Robredo T.          438
# Youzhny M.          428
# Hewitt L.           424
# Wawrinka S.         408
# Lopez F.            405
# Simon G.            389
# Ferrero J.C.        384
# Tsonga J.W.         374
# Monfils G.          372
# Almagro N.          370
# Cilic M.            364
# Kohlschreiber P.    363
# Haas T.             362
# Ljubicic I.         359
# Del Potro J.M.      359
# Stepanek R.         344
# Nalbandian D.       340
# Nieminen J.         333
# Blake J.            333
# Moya C.             331
# Gonzalez F.         324
# Melzer J.           311
# Isner J.            305
# Karlovic I.         305
# Baghdatis M.        305
# Monaco J.           302
# Safin M.            300
# Chela J.I.          293
# Seppi A.            290
# Querrey S.          285
# Name: count, dtype: int64

# %%
loser_count = df['Loser'].value_counts()

# Display the count of wins for each player
print(loser_count.head(40))
loser = loser_count.head(40)
loser
# Out:
# Loser
# Lopez F.            369
# Youzhny M.          345
# Verdasco F.         339
# Ferrer D.           325
# Nieminen J.         308
# Seppi A.            302
# Davydenko N.        299
# Garcia-Lopez G.     299
# Robredo T.          296
# Kohlschreiber P.    291
# Berdych T.          281
# Melzer J.           281
# Mathieu P.H.        273
# Karlovic I.         269
# Simon G.            269
# Montanes A.         262
# Almagro N.          260
# Gasquet R.          260
# Benneteau J.        259
# Stepanek R.         258
# Chela J.I.          252
# Schuettler R.       244
# Baghdatis M.        244
# Ljubicic I.         242
# Monaco J.           237
# Wawrinka S.         236
# Rochus O.           235
# Troicki V.          234
# Mayer F.            233
# Fognini F.          231
# Haas T.             230
# Tipsarevic J.       229
# Clement A.          229
# Malisse X.          228
# Querrey S.          223
# Ferrero J.C.        222
# Monfils G.          220
# Blake J.            219
# Andreev I.          213
# Hanescu V.          210
# Name: count, dtype: int64
# Loser
# Lopez F.            369
# Youzhny M.          345
# Verdasco F.         339
# Ferrer D.           325
# Nieminen J.         308
# Seppi A.            302
# Davydenko N.        299
# Garcia-Lopez G.     299
# Robredo T.          296
# Kohlschreiber P.    291
# Berdych T.          281
# Melzer J.           281
# Mathieu P.H.        273
# Karlovic I.         269
# Simon G.            269
# Montanes A.         262
# Almagro N.          260
# Gasquet R.          260
# Benneteau J.        259
# Stepanek R.         258
# Chela J.I.          252
# Schuettler R.       244
# Baghdatis M.        244
# Ljubicic I.         242
# Monaco J.           237
# Wawrinka S.         236
# Rochus O.           235
# Troicki V.          234
# Mayer F.            233
# Fognini F.          231
# Haas T.             230
# Tipsarevic J.       229
# Clement A.          229
# Malisse X.          228
# Querrey S.          223
# Ferrero J.C.        222
# Monfils G.          220
# Blake J.            219
# Andreev I.          213
# Hanescu V.          210
# Name: count, dtype: int64

# %%
plt.figure(figsize=(40, 20))
sns.barplot(x = winner.index, y = winner.values)
plt.xlabel("Player")
plt.ylabel("Wins")
plt.title("Player Wins Bar Plot")
plt.xticks(rotation=45, ha='right')
plt.show();

# %%
plt.figure(figsize=(40, 20))
sns.barplot(x = loser.index, y = loser.values)
plt.xlabel("Player")
plt.ylabel("Loses")
plt.title("Player Loses Bar Plot")
plt.xticks(rotation=45, ha='right')
plt.show();

# %%
final_games = df[df['Round'] == 'The Final']
final_games_winner = final_games[["Winner", "Tournament", "Date"]]
final_games_winner
tr = tr.drop("Date", axis = 1)
tr = final_games_winner.groupby("Winner")
tr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 4
#       2 final_games_winner = final_games[["Winner", "Tournament", "Date"]]
#       3 final_games_winner
# ----> 4 tr = tr.drop("Date", axis = 1)
#       5 tr = final_games_winner.groupby("Winner")
#       6 tr
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'drop'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

final_games = df[df['Round'] == 'The Final']
final_games_winner = final_games[["Winner", "Tournament"]]

# Grouping by 'Winner' and counting the number of unique tournaments won by each player
player_tournament_wins = final_games_winner.groupby("Winner")["Tournament"].nunique().reset_index(name='TotalTournamentsWon')

# Filtering out players with zero tournament wins
player_tournament_wins = player_tournament_wins[player_tournament_wins['TotalTournamentsWon'] > 0]

# Creating a bar plot using Seaborn
plt.figure(figsize=(15, 8))
sns.barplot(x="Winner", y="TotalTournamentsWon", data=player_tournament_wins, palette="viridis")

# Set labels and title
plt.xlabel('Player')
plt.ylabel('Total Number of Tournaments Won')
plt.title('Total Number of Tournaments Won by Each Player (At Least One Win)')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

final_games = df[df['Round'] == 'The Final']
final_games_winner = final_games[["Winner", "Tournament"]]

# Grouping by 'Winner' and counting the number of unique tournaments won by each player
player_tournament_wins = final_games_winner.groupby("Winner")["Tournament"].size().reset_index(name='TotalTournamentsWon')

# Filtering out players with zero tournament wins
player_tournament_wins = player_tournament_wins[player_tournament_wins['TotalTournamentsWon'] > 0]

# Creating a bar plot using Seaborn
plt.figure(figsize=(15, 8))
sns.barplot(x="Winner", y="TotalTournamentsWon", data=player_tournament_wins, palette="viridis")

# Set labels and title
plt.xlabel('Player')
plt.ylabel('Total Number of Tournaments Won')
plt.title('Total Number of Tournaments Won by Each Player (At Least One Win)')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
tr_max = player_tournament_wins.sort_values("TotalTournamentsWon", ascending = False)

# %%
tr_max
# Out:
#              Winner  TotalTournamentsWon
# 54       Federer R.                   91
# 127        Nadal R.                   70
# 44      Djokovic N.                   60
# 125       Murray A.                   39
# 149      Roddick A.                   29
# ..              ...                  ...
# 19       Boutter J.                    1
# 20     Bracciali D.                    1
# 126      Murray A.                     1
# 21   Burgsmuller L.                    1
# 46         Dodig I.                    1
#
# [195 rows x 2 columns]

# %%
# Creating a bar plot using Seaborn
plt.figure(figsize=(40, 20))
sns.barplot(x=tr_max["Winner"], y=tr_max["TotalTournamentsWon"])

# Set labels and title
plt.xlabel('Player')
plt.ylabel('Total Number of Tournaments Won')
plt.title('Total Number of Tournaments Won by Each Player (At Least One Win)')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

final_games = df[df['Round'] == 'The Final']
final_games_loser = final_games[["Loser", "Tournament"]]

# Grouping by 'Loser' and counting the number of finals lost by each player
player_final_losses = final_games_loser.groupby("Loser")["Tournament"].size().reset_index(name='TotalFinalsLost')

# Filtering out players with zero final losses
player_final_losses = player_final_losses[player_final_losses['TotalFinalsLost'] > 0]

# Sorting by the total number of finals lost in descending order
final_losses_max = player_final_losses.sort_values("TotalFinalsLost", ascending=False)

# Display the result
print(final_losses_max.head())

# Visualizing the result with a bar plot
plt.figure(figsize=(40, 20))
sns.barplot(x="Loser", y="TotalFinalsLost", data=final_losses_max, palette="viridis")

# Set labels and title
plt.xlabel('Player')
plt.ylabel('Total Number of Finals Lost')
plt.title('Total Number of Finals Lost by Each Player (Descending Order)')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot

plt.show()
# Out:
#            Loser  TotalFinalsLost
# 70    Federer R.               39
# 158     Nadal R.               33
# 59   Djokovic N.               29
# 157    Murray A.               22
# 72     Ferrer D.               22
